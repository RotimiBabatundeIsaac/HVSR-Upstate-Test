# %%
conda update all
# Out:
# PackageNotInstalledError: Package is not installed in prefix.
#   prefix: /Users/birotimi/anaconda3
#   package name: all
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install anaconda=2023.09
# Out:
# ...
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# ...
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: |
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# Examining conflict for datasets _anaconda_depends ipykernel dask navigator-upd\

# %%
conda install obspy
# Out:
# ...
# Solving environment: done

# %%
import obspy

# %%
import contourpy

# %%
conda list
# Out:
# # packages in environment at /Users/birotimi/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2023.07                 py311_1
# abseil-cpp                20230802.0           h313beb8_2
# aiobotocore               2.5.0           py311hca03da5_0
# aiofiles                  22.1.0          py311hca03da5_0
# aiohttp                   3.8.5           py311h80987f9_0
# aioitertools              0.7.1              pyhd3eb1b0_0
# aiosignal                 1.2.0              pyhd3eb1b0_0
# aiosqlite                 0.18.0          py311hca03da5_0
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda-anon-usage       0.4.3           py311hd6b623d_100
# anaconda-catalogs         0.2.0           py311hca03da5_0
# anaconda-client           1.12.0          py311hca03da5_0
# anaconda-cloud-auth       0.1.4           py311hca03da5_0
# anaconda-navigator        2.5.0           py311hca03da5_0
# ...

# %%
# !python ./bin/getStationChannelBaseline.py net=IU sta=ANMO loc=00 chan=BHZ start=2002-11-20 end=2008-11-20 plot=1 plotnnm=1 verbose=1 percentlow=10 percenthigh=90
# Out:
# [INFO] getStationChannelBaseline.py, getStationChannelBaseline_param, V.2020.156
# [INFO] libraryPath: /Users/birotimi/Library/CloudStorage/OneDrive-SyracuseUniversity/Desktop/HVSR-master/lib
# [INFO] verbose: 1
# [INFO] plot: 1
# [INFO] plotnnm: 1
# [INFO] Param Path: /Users/birotimi/Library/CloudStorage/OneDrive-SyracuseUniversity/Desktop/HVSR-master/param
# [INFO] loaded: getStationChannelBaseline_param
# [INFO] chan: BHZ
# [INFO] net: IU
# [INFO] sta: ANMO
# [INFO] loc: 00
# [INFO] percentlow: 10
# [INFO] percenthigh: 90
# [INFO] start: 2002-11-20
# [INFO] end: 2008-11-20
# [INFO] requesting IU.ANMO.00.BHZ.M from 2002-11-20 to 2008-11-20
# [INFO] requesting: http://service.iris.edu/mustang/noise-pdf/1/query?target=IU.ANMO.00.BHZ.M&starttime=2002-11-20&endtime=2008-11-20&format=text
# [INFO] waiting for reply....
# [INFO] baseline file: /Users/birotimi/Library/CloudStorage/OneDrive-SyracuseUniversity/Desktop/HVSR-master/data/baseline/IU.ANMO.00.BHZ.txt
# ...

# %%
# !python ./bin/computeHVSR.py net=TA sta=J57A loc= chan=BHZ,BHN,BHE start=2014-01-01 end=2014-01-03 plot=1 plotbad=0 plotpsd=0 plotpdf=1 verbose=1 ymax=20 xtype=frequency n=1 removeoutliers=0 method=4
# Out:
# verbose 1
#
# [INFO] ./bin/computeHVSR.py V.2020.155
# [INFO] remove_outliers: False
# [INFO] DATE LIST: ['2014-01-01', '2014-01-03']
# [INFO] Combining H1 and H2 Using vector summation method
# [INFO] requesting TA.J57A..BHZ.* from 2014-01-01 to 2014-01-03
# [INFO] Doing 2014-01-01T00:00:00 to 2014-01-03T00:00:00
# [INFO] requesting: http://service.iris.edu/mustang/noise-psd/1/query?target=TA.J57A..BHZ.*&starttime=2014-01-01T00:00:00&endtime=2014-01-03T00:00:00&format=xml&correct=true
# [TIME] 0.4 s
# [INFO] PSD waiting for reply....
# [INFO] PSD: 70
# [TIME] 2.9 s
# [INFO] requesting:http://service.iris.edu/mustang/noise-pdf/1/query?target=TA.J57A..BHZ.*&starttime=2014-01-01T00:00:00&endtime=2014-01-03T00:00:00&format=text
# [INFO] PDF waiting for reply....
# [INFO] PDF: 1319
# [INFO] total PSDs:70
# [TIME] 0.7 s
# [INFO] PLOT PSD
# [INFO] Channel BHZ 70 PSDs, 70 accepted and 0 rejected
#
# ...

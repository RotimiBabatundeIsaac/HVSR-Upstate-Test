# %%
conda install obspy
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
% conda install conda
# Out:
# UsageError: Line magic function `%` not found.

# %%
conda list
# Out:
# # packages in environment at /Users/birotimi/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2023.07                 py311_1
# abseil-cpp                20211102.0           hc377ac9_0
# aiobotocore               2.5.0           py311hca03da5_0
# aiofiles                  22.1.0          py311hca03da5_0
# aiohttp                   3.8.5           py311h80987f9_0
# aioitertools              0.7.1              pyhd3eb1b0_0
# aiosignal                 1.2.0              pyhd3eb1b0_0
# aiosqlite                 0.18.0          py311hca03da5_0
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda-anon-usage       0.4.2           py311hd6b623d_2
# anaconda-catalogs         0.2.0           py311hca03da5_0
# anaconda-client           1.12.0          py311hca03da5_0
# anaconda-cloud-auth       0.1.3           py311hca03da5_0
# anaconda-navigator        2.5.0           py311hca03da5_0
# ...

# %%
from obspy import read

# %%
ls
# Out:
# BK.SAO.00.VHZ.Q.2021.284.044550.SAC  bin/
# CHANGES.txt                          data/
# INSTALL.txt                          image/
# LICENSE                              lib/
# README.md                            param/
# Untitled.ipynb                       scratch/
# Untitled1.ipynb

# %%
st = read('BK.SAO.00.VHZ.Q.2021.284.044550.sac', debug_headers=True)

# %%
st
# Out:
# 1 Trace(s) in Stream:
# BK.SAO.00.VHZ | 2021-10-11T04:45:50.069538Z - 2021-10-11T06:50:40.069426Z | 0.1 Hz, 750 samples

# %%
print (st)
# Out:
# 1 Trace(s) in Stream:
# BK.SAO.00.VHZ | 2021-10-11T04:45:50.069538Z - 2021-10-11T06:50:40.069426Z | 0.1 Hz, 750 samples

# %%
print (st[0].stats)
# Out:
#          network: BK
#          station: SAO
#         location: 00
#          channel: VHZ
#        starttime: 2021-10-11T04:45:50.069538Z
#          endtime: 2021-10-11T06:50:40.069426Z
#    sampling_rate: 0.10000000149011612
#            delta: 9.99999985098839
#             npts: 750
#            calib: 4113770000.0
#          _format: SAC
# ...
